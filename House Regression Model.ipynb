# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
house = pd.read_csv('house.csv')
house
# Out:
#         price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0      221900         3       1.00         1180      5650     1.0           0
# 1      538000         3       2.25         2570      7242     2.0           0
# 2      180000         2       1.00          770     10000     1.0           0
# 3      604000         4       3.00         1960      5000     1.0           0
# 4      510000         3       2.00         1680      8080     1.0           0
# ...       ...       ...        ...          ...       ...     ...         ...
# 21608  360000         3       2.50         1530      1131     3.0           0
# 21609  400000         4       2.50         2310      5813     2.0           0
# 21610  402101         2       0.75         1020      1350     2.0           0
# 21611  400000         3       2.50         1600      2388     2.0           0
# 21612  325000         2       0.75         1020      1076     2.0           0
#
# ...

# %%
house.dropna(inplace=True)

# %%
house
# Out:
#         price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0      221900         3       1.00         1180      5650     1.0           0
# 1      538000         3       2.25         2570      7242     2.0           0
# 2      180000         2       1.00          770     10000     1.0           0
# 3      604000         4       3.00         1960      5000     1.0           0
# 4      510000         3       2.00         1680      8080     1.0           0
# ...       ...       ...        ...          ...       ...     ...         ...
# 21608  360000         3       2.50         1530      1131     3.0           0
# 21609  400000         4       2.50         2310      5813     2.0           0
# 21610  402101         2       0.75         1020      1350     2.0           0
# 21611  400000         3       2.50         1600      2388     2.0           0
# 21612  325000         2       0.75         1020      1076     2.0           0
#
# ...

# %%
house.drop(columns=['sqft_lot15','lat','sqft_lot','long','sqft_living15','waterfront','view'], axis=1, inplace=True)

# %%
house
# Out:
#         price  bedrooms  bathrooms  sqft_living  floors  condition  grade  \
# 0      221900         3       1.00         1180     1.0          3      7
# 1      538000         3       2.25         2570     2.0          3      7
# 2      180000         2       1.00          770     1.0          3      6
# 3      604000         4       3.00         1960     1.0          5      7
# 4      510000         3       2.00         1680     1.0          3      8
# ...       ...       ...        ...          ...     ...        ...    ...
# 21608  360000         3       2.50         1530     3.0          3      8
# 21609  400000         4       2.50         2310     2.0          3      8
# 21610  402101         2       0.75         1020     2.0          3      7
# 21611  400000         3       2.50         1600     2.0          3      8
# 21612  325000         2       0.75         1020     2.0          3      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode
# ...

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          21613 non-null  int64
#  1   bedrooms       21613 non-null  int64
#  2   bathrooms      21613 non-null  float64
#  3   sqft_living    21613 non-null  int64
#  4   floors         21613 non-null  float64
#  5   condition      21613 non-null  int64
#  6   grade          21613 non-null  int64
#  7   sqft_above     21613 non-null  int64
#  8   sqft_basement  21613 non-null  int64
#  9   yr_built       21613 non-null  int64
#  10  yr_renovated   21613 non-null  int64
#  11  zipcode        21613 non-null  int64
# dtypes: float64(2), int64(10)
# memory usage: 2.0 MB

# %%
house['bathrooms'] = house['bathrooms'].astype(int)

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          21613 non-null  int64
#  1   bedrooms       21613 non-null  int64
#  2   bathrooms      21613 non-null  int32
#  3   sqft_living    21613 non-null  int64
#  4   floors         21613 non-null  float64
#  5   condition      21613 non-null  int64
#  6   grade          21613 non-null  int64
#  7   sqft_above     21613 non-null  int64
#  8   sqft_basement  21613 non-null  int64
#  9   yr_built       21613 non-null  int64
#  10  yr_renovated   21613 non-null  int64
#  11  zipcode        21613 non-null  int64
# dtypes: float64(1), int32(1), int64(10)
# memory usage: 1.9 MB

# %%
house['floors'] = house['floors'].astype(int)

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          21613 non-null  int64
#  1   bedrooms       21613 non-null  int64
#  2   bathrooms      21613 non-null  int32
#  3   sqft_living    21613 non-null  int64
#  4   floors         21613 non-null  int32
#  5   condition      21613 non-null  int64
#  6   grade          21613 non-null  int64
#  7   sqft_above     21613 non-null  int64
#  8   sqft_basement  21613 non-null  int64
#  9   yr_built       21613 non-null  int64
#  10  yr_renovated   21613 non-null  int64
#  11  zipcode        21613 non-null  int64
# dtypes: int32(2), int64(10)
# memory usage: 1.8 MB

# %%
house.reset_index(drop=True)
# Out:
#         price  bedrooms  bathrooms  sqft_living  floors  condition  grade  \
# 0      221900         3          1         1180       1          3      7
# 1      538000         3          2         2570       2          3      7
# 2      180000         2          1          770       1          3      6
# 3      604000         4          3         1960       1          5      7
# 4      510000         3          2         1680       1          3      8
# ...       ...       ...        ...          ...     ...        ...    ...
# 21608  360000         3          2         1530       3          3      8
# 21609  400000         4          2         2310       2          3      8
# 21610  402101         2          0         1020       2          3      7
# 21611  400000         3          2         1600       2          3      8
# 21612  325000         2          0         1020       2          3      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode
# ...

# %%
X = house.drop(['price', 'yr_built', 'yr_renovated', 'zipcode', 'sqft_above', 'sqft_basement'], axis=1)
y = house['price']
y = y.values.reshape(-1,1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=234)

# %%
from sklearn.metrics import r2_score

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
y_pred
# Out:
# array([[561063.04914427],
#        [725598.86657731],
#        [865916.32421925],
#        ...,
#        [836531.13353852],
#        [307514.71050959],
#        [132014.2491768 ]])

# %%
r2_score(y_test, y_pred)
# Out:
# 0.5959985680088673

# %%
score = []
for i in range(1000):
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=i)
    lr = LinearRegression()
    lr.fit(X_train, y_train)
    y_pred = lr.predict(X_test)
    score.append(r2_score(y_test, y_pred))

# %%
np.argmax(score)
# Out:
# 234

# %%
score[52]
# Out:
# 0.5907500903165236

# %%
X_test
# Out:
#        bedrooms  bathrooms  sqft_living  floors  condition  grade
# 10033         4          1         2000       1          3      7
# 20870         3          2         1890       2          3      7
# 21323         3          3         3530       2          3     10
# 12147         3          1         1660       1          3      7
# 15145         2          1         1290       1          3      7
# ...         ...        ...          ...     ...        ...    ...
# 19127         3          2         2430       2          3      8
# 4202          3          2         3240       2          3      7
# 16669         4          2         2040       2          3      8
# 19332         3          2         1670       2          4      7
# 2289          3          1         1780       1          3      7
#
# [4323 rows x 6 columns]

# %%
lr.predict(pd.DataFrame([[4,1,2000,1,3,7]], columns=['bedrooms','bathrooms','sqft_living','floors','condition','grade']))
# Out:
# array([[404516.27707804]])

# %%
y_test
# Out:
# array([[ 228000],
#        [ 409000],
#        [1500000],
#        ...,
#        [ 500000],
#        [ 289000],
#        [ 354950]], dtype=int64)

# %% [markdown]
# ## Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly  = PolynomialFeatures(degree=1)

# %%
X_poly = poly.fit_transform(X_train)

# %%
X_poly
# Out:
# array([[1., 4., 2., ..., 1., 4., 6.],
#        [1., 3., 2., ..., 2., 3., 8.],
#        [1., 2., 1., ..., 1., 4., 6.],
#        ...,
#        [1., 2., 1., ..., 1., 3., 8.],
#        [1., 5., 1., ..., 1., 3., 7.],
#        [1., 3., 3., ..., 2., 3., 8.]])

# %%
L1 = LinearRegression()

# %%
L1.fit(X_poly, y_train)
# Out:
# LinearRegression()

# %%
X_test_poly = poly.fit_transform(X_test)

# %%
y_pred = L1.predict(X_test_poly)

# %%
y_pred
# Out:
# array([[ 404516.27707805],
#        [ 404383.00539333],
#        [1086464.89563793],
#        ...,
#        [ 490340.96083772],
#        [ 415864.43717875],
#        [ 407887.69604719]])

# %%
r2_score(y_test, y_pred)
# Out:
# 0.5804108109461523
